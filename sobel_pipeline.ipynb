# %% [markdown]
# <a href="https://colab.research.google.com/github/MN-21/MN-1/blob/main/sobel_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install --quiet tensorflow tensorflow-datasets opencv-python scikit-learn tqdm

import cv2
import time
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# 1. Contour-gradient-free Sobel feature extractor (full-image gradients)
def compute_gradients(images):
    """
    Given a NumPy array of shape (N,28,28), returns
    an array of shape (N, 2, 28, 28) containing normalized gx, gy.
    """
    N = images.shape[0]
    grads = np.zeros((N, 2, 28, 28), dtype=np.float32)
    for i, img in enumerate(tqdm(images, desc="Computing gradients")):
        gx = cv2.Sobel(img, cv2.CV_32F, 1, 0, ksize=3)
        gy = cv2.Sobel(img, cv2.CV_32F, 0, 1, ksize=3)
        # normalize each to [0,1]
        gx = (gx - gx.min()) / (gx.max() - gx.min() + 1e-8)
        gy = (gy - gy.min()) / (gy.max() - gy.min() + 1e-8)
        grads[i,0] = gx
        grads[i,1] = gy
    return grads

# 2. Load EMNIST Letters via TFDS
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/letters',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# 3. Convert to NumPy arrays
all_images = []
all_labels = []
for img, lbl in tfds.as_numpy(ds_train.concatenate(ds_test)):
    all_images.append(img.squeeze())        # shape (28,28)
    all_labels.append(int(lbl) - 1)         # shift labels 1–26 → 0–25
all_images = np.stack(all_images)           # (145600,28,28)
all_labels = np.array(all_labels, dtype=int)

# 4. Stratified 80/20 train/test split
X_train, X_test, y_train, y_test = train_test_split(
    all_images, all_labels,
    train_size=0.8,
    stratify=all_labels,
    random_state=42
)

# 5. Compute Sobel gradient features
grad_train = compute_gradients(X_train)
grad_test  = compute_gradients(X_test)

# 6. Flatten to feature vectors (2*28*28 = 1568 dims)
X_train_feat = grad_train.reshape(-1, 2*28*28)
X_test_feat  = grad_test.reshape(-1, 2*28*28)

# 7. Build MLP model
model = models.Sequential([
    layers.Input(shape=(2*28*28,)),
    layers.Dense(1024), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(512), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.4),

    layers.Dense(256), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.3),

    layers.Dense(26, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 8. Callbacks
es = callbacks.EarlyStopping(
    monitor='val_accuracy', patience=50,
    restore_best_weights=True, verbose=1
)
rlr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5,
    patience=3, min_lr=1e-6, verbose=1
)

# 9. Train
t0 = time.time()
history = model.fit(
    X_train_feat, y_train,
    validation_split=0.1,
    epochs=100,
    batch_size=128,
    callbacks=[es, rlr],
    verbose=2
)
train_time = time.time() - t0

# 10. Evaluate
t1 = time.time()
test_loss, test_acc = model.evaluate(X_test_feat, y_test, verbose=2)
infer_time = time.time() - t1

# 11. Report
print(f"\nEMNIST Letters Sobel-Gradient MLP")
print(f"Test Accuracy   : {test_acc*100:.2f}%")
print(f"Training Time   : {train_time:.1f}s")
print(f"Inference Time  : {infer_time:.1f}s for {X_test_feat.shape[0]} samples")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/emnist/letters/3.1.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/emnist/letters/3.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/emnist/letters/incomplete.SL5PNH_3.1.0/emnist-train.tfrecord*...:   0%|   …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/emnist/letters/incomplete.SL5PNH_3.1.0/emnist-test.tfrecord*...:   0%|    …
# Dataset emnist downloaded and prepared to /root/tensorflow_datasets/emnist/letters/3.1.0. Subsequent calls will reuse this data.
# Computing gradients: 100%|██████████| 82880/82880 [00:04<00:00, 17658.12it/s]
# Computing gradients: 100%|██████████| 20720/20720 [00:01<00:00, 13226.89it/s]
# Epoch 1/100
# 583/583 - 36s - 62ms/step - accuracy: 0.6430 - loss: 1.1872 - val_accuracy: 0.5878 - val_loss: 1.2808 - learning_rate: 1.0000e-03
# Epoch 2/100
# 583/583 - 41s - 71ms/step - accuracy: 0.7847 - loss: 0.6850 - val_accuracy: 0.4002 - val_loss: 2.8197 - learning_rate: 1.0000e-03
# Epoch 3/100
# 583/583 - 41s - 71ms/step - accuracy: 0.8226 - loss: 0.5584 - val_accuracy: 0.4779 - val_loss: 1.9825 - learning_rate: 1.0000e-03
# Epoch 4/100
# 583/583 - 41s - 70ms/step - accuracy: 0.8425 - loss: 0.4870 - val_accuracy: 0.7191 - val_loss: 0.9176 - learning_rate: 1.0000e-03
# Epoch 5/100
# 583/583 - 41s - 70ms/step - accuracy: 0.8545 - loss: 0.4464 - val_accuracy: 0.6889 - val_loss: 0.9595 - learning_rate: 1.0000e-03
# Epoch 6/100
# 583/583 - 40s - 69ms/step - accuracy: 0.8639 - loss: 0.4141 - val_accuracy: 0.6805 - val_loss: 1.0622 - learning_rate: 1.0000e-03
# Epoch 7/100
# 583/583 - 42s - 72ms/step - accuracy: 0.8716 - loss: 0.3869 - val_accuracy: 0.8067 - val_loss: 0.5815 - learning_rate: 1.0000e-03
# Epoch 8/100
# 583/583 - 32s - 55ms/step - accuracy: 0.8790 - loss: 0.3627 - val_accuracy: 0.6641 - val_loss: 1.1065 - learning_rate: 1.0000e-03
# Epoch 9/100
# 583/583 - 41s - 70ms/step - accuracy: 0.8848 - loss: 0.3467 - val_accuracy: 0.8209 - val_loss: 0.5523 - learning_rate: 1.0000e-03
# Epoch 10/100
# 583/583 - 43s - 73ms/step - accuracy: 0.8855 - loss: 0.3371 - val_accuracy: 0.7938 - val_loss: 0.6474 - learning_rate: 1.0000e-03
# Epoch 11/100
# 583/583 - 40s - 69ms/step - accuracy: 0.8928 - loss: 0.3169 - val_accuracy: 0.8149 - val_loss: 0.5448 - learning_rate: 1.0000e-03
# Epoch 12/100
# 583/583 - 41s - 71ms/step - accuracy: 0.8967 - loss: 0.3057 - val_accuracy: 0.7642 - val_loss: 0.7582 - learning_rate: 1.0000e-03
# Epoch 13/100
# 583/583 - 40s - 68ms/step - accuracy: 0.8998 - loss: 0.2919 - val_accuracy: 0.8514 - val_loss: 0.4625 - learning_rate: 1.0000e-03
# Epoch 14/100
# 583/583 - 41s - 71ms/step - accuracy: 0.9028 - loss: 0.2856 - val_accuracy: 0.8290 - val_loss: 0.5446 - learning_rate: 1.0000e-03
# Epoch 15/100
# 583/583 - 43s - 73ms/step - accuracy: 0.9056 - loss: 0.2746 - val_accuracy: 0.8694 - val_loss: 0.3987 - learning_rate: 1.0000e-03
# Epoch 16/100
# 583/583 - 40s - 69ms/step - accuracy: 0.9083 - loss: 0.2651 - val_accuracy: 0.8662 - val_loss: 0.4085 - learning_rate: 1.0000e-03
# Epoch 17/100
# 583/583 - 42s - 72ms/step - accuracy: 0.9080 - loss: 0.2646 - val_accuracy: 0.8267 - val_loss: 0.5806 - learning_rate: 1.0000e-03
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 583/583 - 33s - 56ms/step - accuracy: 0.9109 - loss: 0.2566 - val_accuracy: 0.8263 - val_loss: 0.5530 - learning_rate: 1.0000e-03
# Epoch 19/100
# 583/583 - 34s - 58ms/step - accuracy: 0.9207 - loss: 0.2250 - val_accuracy: 0.8968 - val_loss: 0.2990 - learning_rate: 5.0000e-04
# Epoch 20/100
# 583/583 - 40s - 69ms/step - accuracy: 0.9240 - loss: 0.2164 - val_accuracy: 0.9087 - val_loss: 0.2667 - learning_rate: 5.0000e-04
# Epoch 21/100
# 583/583 - 41s - 70ms/step - accuracy: 0.
100
# 583/583 - 40s - 69ms/step - accuracy: 0.9470 - loss: 0.1392 - val_accuracy: 0.9289 - val_loss: 0.2257 - learning_rate: 1.0000e-06
# Epoch 83/100
# 583/583 - 40s - 69ms/step - accuracy: 0.9468 - loss: 0.1407 - val_accuracy: 0.9287 - val_loss: 0.2255 - learning_rate: 1.0000e-06
# Epoch 84/100
# 583/583 - 34s - 59ms/step - accuracy: 0.9463 - loss: 0.1419 - val_accuracy: 0.9291 - val_loss: 0.2252 - learning_rate: 1.0000e-06
# Epoch 85/100
# 583/583 - 33s - 56ms/step - accuracy: 0.9473 - loss: 0.1410 - val_accuracy: 0.9291 - val_loss: 0.2256 - learning_rate: 1.0000e-06
# Epoch 86/100
# 583/583 - 33s - 57ms/step - accuracy: 0.9473 - loss: 0.1403 - val_accuracy: 0.9289 - val_loss: 0.2257 - learning_rate: 1.0000e-06
# Epoch 87/100
# 583/583 - 41s - 70ms/step - accuracy: 0.9482 - loss: 0.1384 - val_accuracy: 0.9289 - val_loss: 0.2254 - learning_rate: 1.0000e-06
# Epoch 87: early stopping
# Restoring model weights from the end of the best epoch: 37.
# 648/648 - 5s - 8ms/step - accuracy: 0.9267 - loss: 0.2347
#
# EMNIST Letters Sobel-Gradient MLP
# Test Accuracy   : 92.67%
# Training Time   : 3434.8s
# Inference Time  : 5.5s for 20720 samples

# %%
# Install dependencies
# !pip install --quiet tensorflow tensorflow-datasets opencv-python tqdm scikit-learn

import cv2
import time
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# 1. Sobel feature extractor (full-image gradients)
def compute_gradients(images):
    """
    Given a NumPy array of shape (N,28,28), returns
    an array of shape (N, 2, 28, 28) containing normalized gx, gy.
    """
    N = images.shape[0]
    grads = np.zeros((N, 2, 28, 28), dtype=np.float32)
    for i, img in enumerate(tqdm(images, desc="Computing gradients")):
        gx = cv2.Sobel(img, cv2.CV_32F, 1, 0, ksize=3)
        gy = cv2.Sobel(img, cv2.CV_32F, 0, 1, ksize=3)
        # normalize each to [0,1]
        gx = (gx - gx.min()) / (gx.max() - gx.min() + 1e-8)
        gy = (gy - gy.min()) / (gy.max() - gy.min() + 1e-8)
        grads[i,0] = gx
        grads[i,1] = gy
    return grads

# 2. Load MNIST via TFDS
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# 3. Convert to NumPy arrays
all_images = []
all_labels = []
for img, lbl in tfds.as_numpy(ds_train.concatenate(ds_test)):
    all_images.append(img.squeeze())  # shape (28,28)
    all_labels.append(int(lbl))       # labels 0–9
all_images = np.stack(all_images)    # (70000,28,28)
all_labels = np.array(all_labels, dtype=int)

# 4. Stratified 80/20 train/test split
X_train, X_test, y_train, y_test = train_test_split(
    all_images, all_labels,
    train_size=0.8,
    stratify=all_labels,
    random_state=42
)

# 5. Compute Sobel gradient features
grad_train = compute_gradients(X_train)
grad_test  = compute_gradients(X_test)

# 6. Flatten to feature vectors (2*28*28 = 1568 dims)
X_train_feat = grad_train.reshape(-1, 2*28*28)
X_test_feat  = grad_test.reshape(-1, 2*28*28)

# 7. Build MLP model for 10 classes
model = models.Sequential([
    layers.Input(shape=(2*28*28,)),
    layers.Dense(1024), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(512), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.4),

    layers.Dense(256), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.3),

    layers.Dense(10, activation='softmax')  # 10 output classes for MNIST digits
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 8. Callbacks
es = callbacks.EarlyStopping(
    monitor='val_accuracy', patience=4,
    restore_best_weights=True, verbose=1
)
rlr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5,
    patience=3, min_lr=1e-6, verbose=1
)

# 9. Train
t0 = time.time()
history = model.fit(
    X_train_feat, y_train,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[es, rlr],
    verbose=2
)
train_time = time.time() - t0

# 10. Evaluate
t1 = time.time()
test_loss, test_acc = model.evaluate(X_test_feat, y_test, verbose=2)
infer_time = time.time() - t1

# 11. Report
print(f"\nMNIST Sobel-Gradient MLP")
print(f"Test Accuracy   : {test_acc*100:.2f}%")
print(f"Training Time   : {train_time:.1f}s")
print(f"Inference Time  : {infer_time:.1f}s for {X_test_feat.shape[0]} samples")
# Out:
# Computing gradients: 100%|██████████| 56000/56000 [00:04<00:00, 12783.60it/s]
# Computing gradients: 100%|██████████| 14000/14000 [00:01<00:00, 8979.41it/s]
# Epoch 1/50
# 394/394 - 26s - 65ms/step - accuracy: 0.8868 - loss: 0.3671 - val_accuracy: 0.5641 - val_loss: 1.4826 - learning_rate: 1.0000e-03
# Epoch 2/50
# 394/394 - 20s - 50ms/step - accuracy: 0.9463 - loss: 0.1740 - val_accuracy: 0.5105 - val_loss: 2.3724 - learning_rate: 1.0000e-03
# Epoch 3/50
# 394/394 - 22s - 55ms/step - accuracy: 0.9573 - loss: 0.1349 - val_accuracy: 0.5814 - val_loss: 1.6609 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 394/394 - 40s - 101ms/step - accuracy: 0.9646 - loss: 0.1136 - val_accuracy: 0.5375 - val_loss: 1.6551 - learning_rate: 1.0000e-03
# Epoch 5/50
# 394/394 - 22s - 57ms/step - accuracy: 0.9747 - loss: 0.0817 - val_accuracy: 0.9350 - val_loss: 0.2155 - learning_rate: 5.0000e-04
# Epoch 6/50
# 394/394 - 39s - 98ms/step - accuracy: 0.9774 - loss: 0.0690 - val_accuracy: 0.7268 - val_loss: 1.1263 - learning_rate: 5.0000e-04
# Epoch 7/50
# 394/394 - 22s - 55ms/step - accuracy: 0.9800 - loss: 0.0634 - val_accuracy: 0.6745 - val_loss: 1.5530 - learning_rate: 5.0000e-04
# Epoch 8/50
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 394/394 - 20s - 52ms/step - accuracy: 0.9805 - loss: 0.0587 - val_accuracy: 0.8839 - val_loss: 0.3659 - learning_rate: 5.0000e-04
# Epoch 9/50
# 394/394 - 20s - 52ms/step - accuracy: 0.9833 - loss: 0.0514 - val_accuracy: 0.9693 - val_loss: 0.1073 - learning_rate: 2.5000e-04
# Epoch 10/50
# 394/394 - 21s - 54ms/step - accuracy: 0.9855 - loss: 0.0432 - val_accuracy: 0.9652 - val_loss: 0.1251 - learning_rate: 2.5000e-04
# Epoch 11/50
# 394/394 - 20s - 50ms/step - accuracy: 0.9868 - loss: 0.0400 - val_accuracy: 0.9618 - val_loss: 0.1406 - learning_rate: 2.5000e-04
# Epoch 12/50
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 394/394 - 21s - 54ms/step - accuracy: 0.9879 - loss: 0.0370 - val_accuracy: 0.9007 - val_loss: 0.3479 - learning_rate: 2.5000e-04
# Epoch 13/50
# 394/394 - 40s - 101ms/step - accuracy: 0.9902 - loss: 0.0305 - val_accuracy: 0.9796 - val_loss: 0.0732 - learning_rate: 1.2500e-04
# Epoch 14/50
# 394/394 - 21s - 54ms/step - accuracy: 0.9897 - loss: 0.0306 - val_accuracy: 0.9779 - val_loss: 0.0844 - learning_rate: 1.2500e-04
# Epoch 15/50
# 394/394 - 42s - 106ms/step - accuracy: 0.9908 - loss: 0.0282 - val_accuracy: 0.9796 - val_loss: 0.0754 - learning_rate: 1.2500e-04
# Epoch 16/50
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 394/394 - 40s - 102ms/step - accuracy: 0.9911 - loss: 0.0272 - val_accuracy: 0.9755 - val_loss: 0.0946 - learning_rate: 1.2500e-04
# Epoch 17/50
# 394/394 - 40s - 101ms/step - accuracy: 0.9918 - loss: 0.0249 - val_accuracy: 0.9825 - val_loss: 0.0691 - learning_rate: 6.2500e-05
# Epoch 18/50
# 394/394 - 22s - 55ms/step - accuracy: 0.9918 - loss: 0.0246 - val_accuracy: 0.9823 - val_loss: 0.0677 - learning_rate: 6.2500e-05
# Epoch 19/50
# 394/394 - 20s - 51ms/step - accuracy: 0.9915 - loss: 0.0257 - val_accuracy: 0.9809 - val_loss: 0.0706 - learning_rate: 6.2500e-05
# Epoch 20/50
# 394/394 - 21s - 53ms/step - accuracy: 0.9926 - loss: 0.0230 - val_accuracy: 0.9829 - val_loss: 0.0673 - learning_rate: 6.2500e-05
# Epoch 21/50
# 394/394 - 21s - 53ms/step - accuracy: 0.9930 - loss: 0.0216 - val_accuracy: 0.9795 - val_loss: 0.0780 - learning_rate: 6.2500e-05
# Epoch 22/50
# 394/394 - 42s - 107ms/step - accuracy: 0.9929 - loss: 0.0218 - val_accuracy: 0.9829 - val_loss: 0.0694 - learning_rate: 6.2500e-05
# Epoch 23/50
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 394/394 - 39s - 99ms/step - accuracy: 0.9928 - loss: 0.0221 - val_accuracy: 0.9800 - val_loss: 0.0791 - learning_rate: 6.2500e-05
# Epoch 24/50
# 394/394 - 21s - 54ms/step - accuracy: 0.9938 - loss: 0.0197 - val_accuracy: 0.9830 - val_loss: 0.0676 - learning_rate: 3.1250e-05
# Epoch 25/50
# 394/394 - 40s - 102ms/step - accuracy: 0.9930 - loss: 0.0207 - val_accuracy: 0.9827 - val_loss: 0.0690 - learning_rate: 3.1250e-05
# Epoch 26/50
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 394/394 - 21s - 54ms/step - accuracy: 0.9937 - loss: 0.0191 - val_accuracy: 0.9832 - val_loss: 0.0690 - learning_rate: 3.1250e-05
# Epoch 27/50
# 394/394 - 41s - 103ms/step - accuracy: 0.9940 - loss: 0.0183 - val_accuracy: 0.9836 - val_loss: 0.0677 - learning_rate: 1.5625e-05
# Epoch 28/50
# 394/394 - 20s - 51ms/step - accuracy: 0.9932 - loss: 0.0195 - val_accuracy: 0.9843 - val_loss: 0.0659 - learning_rate: 1.5625e-05
# Epoch 29/50
# 394/394 - 21s - 53ms/step - accuracy: 0.9941 - loss: 0.0182 - val_accuracy: 0.9830 - val_loss: 0.0664 - learning_rate: 1.5625e-05
# Epoch 30/50
# 394/394 - 41s - 104ms/step - accuracy: 0.9941 - loss: 0.0176 - val_accuracy: 0.9827 - val_loss: 0.0669 - learning_rate: 1.5625e-05
# Epoch 31/50
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 394/394 - 41s - 104ms/step - accuracy: 0.9940 - loss: 0.0180 - val_accuracy: 0.9834 - val_loss: 0.0667 - learning_rate: 1.5625e-05
# Epoch 32/50
# 394/394 - 41s - 105ms/step - accuracy: 0.9946 - loss: 0.0173 - val_accuracy: 0.9836 - val_loss: 0.0661 - learning_rate: 7.8125e-06
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 28.
# 438/438 - 3s - 7ms/step - accuracy: 0.9857 - loss: 0.0579
#
# MNIST Sobel-Gradient MLP
# Test Accuracy   : 98.57%
# Training Time   : 928.5s
# Inference Time  : 3.2s for 14000 samples
